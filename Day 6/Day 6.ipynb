# %%
with open('i.txt') as file:
    questions = file.read().split('\n\n')

# %%
distinct_count = 0
common_count = 0
for q in questions:
    distinct_count += len(set.union(*[set(answer) for answer in q.split('\n')]))
    common_count += len(set.intersection(*[set(answer) for answer in q.split('\n')]))

# %%
print(distinct_count)
print(common_count)
# Out:
# 6542
# 3299
